# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np

# %%
plt.figure(figsize=(10, 10))
xval = np.arange(200)

with open(f'/baldig/proteomics2/ian/Neural-Balance/personalExps/transformer/hist/Transformer-lr_0.0001-l2Weight_0-seed_100-neuralBalance_0-neuralBalanceAtStart_0.pkl', 'rb') as f:
    arr = pickle.load(f)['test_acc']
    plt.plot(xval, arr, 'blue', label='clean w/o neural balance at start')

with open(f'/baldig/proteomics2/ian/Neural-Balance/personalExps/transformer/hist/Transformer-lr_0.0001-l2Weight_0-seed_100-neuralBalance_0-neuralBalanceAtStart_1.pkl', 'rb') as f:
    arr = pickle.load(f)['test_acc']
    plt.plot(xval, arr, 'red', label='clean w neural balance at start')

with open(f'/baldig/proteomics2/ian/Neural-Balance/personalExps/transformer/hist/Transformer-lr_0.0001-l2Weight_1e-05-seed_100-neuralBalance_0-neuralBalanceAtStart_0.pkl', 'rb') as f:
    arr = pickle.load(f)['test_acc']
    plt.plot(xval, arr, 'green', label='L2 w/o neural balance at start')

with open(f'/baldig/proteomics2/ian/Neural-Balance/personalExps/transformer/hist/Transformer-lr_0.0001-l2Weight_1e-05-seed_100-neuralBalance_0-neuralBalanceAtStart_1.pkl', 'rb') as f:
    arr = pickle.load(f)['test_acc']
    plt.plot(xval, arr, 'orange', label='L2 w neural balance at start')

with open(f'/baldig/proteomics2/ian/Neural-Balance/personalExps/transformer/hist/Transformer-lr_0.0001-l2Weight_0-seed_100-neuralBalance_1-neuralBalanceAtStart_1.pkl', 'rb') as f:
    arr = pickle.load(f)['test_acc']
    plt.plot(xval, arr, 'black', label='NB w neural balance at start')

with open(f'/baldig/proteomics2/ian/Neural-Balance/personalExps/transformer/hist/Transformer-lr_0.0001-l2Weight_0-seed_100-neuralBalance_1-neuralBalanceAtStart_0.pkl', 'rb') as f:
    arr = pickle.load(f)['test_acc']
    plt.plot(xval, arr, 'yellow', label='NB w/o neural balance at start')

plt.legend(fontsize=16)
plt.ylabel('Accuracy', fontsize = 22)
plt.xlabel('Epochs', fontsize = 22)
plt.tick_params(axis='y', labelsize=16)
plt.tick_params(axis='x', labelsize=16)
plt.yticks(np.arange(.6, .85, .05))
plt.title('Transformer Model with 6 Transformer Blocks', fontsize = 22)
plt.savefig('transformer.pdf', dpi=1000)
