# %%
#https://github.com/christianversloot/machine-learning-articles/blob/main/how-to-use-l1-l2-and-elastic-net-regularization-with-pytorch.md#

# %%
import os
import torch
from torch import nn
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
from torchvision import transforms

from models import *

# %%
class CustomLinear(nn.Module):
    def __init__(self, input_features, output_features, bias=True):
        super(CustomLinear, self).__init__()
        # Use the nn.Linear layer internally
        self.linear = nn.Linear(input_features, output_features, bias)
        
    @property
    def weight(self):
        return self.linear.weight

    def forward(self, input):
        # Forward pass through the internal nn.Linear layer
        return self.linear(input)
    
    def neural_balance(self, previous_layer, return_norms = False, random_perc = 0.1):
        shape = previous_layer.weight.shape[0]
        norm = []
        
        incoming = torch.linalg.norm(previous_layer.weight, dim=1, ord=2)
        outgoing = torch.linalg.norm(self.linear.weight, dim=0, ord=2)
        optimal_l = torch.sqrt(outgoing/incoming)
        print(optimal_l)
        previous_layer.weight.data *= optimal_l.unsqueeze(1)
        self.linear.weight.data /= optimal_l
        if return_norms:
            norm.append(torch.linalg.norm(incoming/outgoing, dim = 0, ord=2))
        if return_norms: return torch.mean(torch.stack(norm))
        else: return torch.tensor([])

# %%
class MLP(nn.Module):
    '''
    Multilayer Perceptron.
    '''
    def __init__(self):
        super().__init__()
        self.layers = nn.Sequential(
          nn.Flatten(),
          CustomLinear(28 * 28 * 1, 256),
          nn.ReLU(),
#           nn.Linear(256, 256),
#           nn.ReLU(),
          CustomLinear(256, 128),
          nn.ReLU(),
          CustomLinear(128, 64),
          nn.ReLU(),
#           nn.Linear(64, 64),
#           nn.ReLU(),
          CustomLinear(64, 10)
        )


    def forward(self, x):
        '''Forward pass'''
        return self.layers(x)

    def compute_l1_loss(self, w):
        return torch.abs(w).sum()

    def compute_l2_loss(self, w):
        return torch.square(w).sum()

# %% [markdown]
# ## training with neural balance

# %%
if __name__ == '__main__':

    # Check if GPU is available
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print(f"Training on {device}")

    # Set fixed random number seed
    torch.manual_seed(42)
    
    epochs = 2

    # Prepare MNIST dataset
    train_dataset = MNIST(os.getcwd(), train=True, download=True, transform=transforms.ToTensor())
    test_dataset = MNIST(os.getcwd(), train=False, download=True, transform=transforms.ToTensor())
    
    trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=256, shuffle=True, num_workers=1)
    testloader = torch.utils.data.DataLoader(test_dataset, batch_size=256, shuffle=False, num_workers=1)

    # Initialize the MLP
    mlp = MLP().to(device)
    
    linear_layers = []
    accuracies= []
    norms = []

    for layer in mlp.layers:
        if(isinstance(layer, CustomLinear)):
            linear_layers.append(layer)

    # Define the loss function and optimizer
    loss_function = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(mlp.parameters(), lr=1e-3)

    # Run the training loop
    for epoch in range(epochs): # 5 epochs at maximum

        # Print epoch
        print(f'Starting epoch {epoch+1}')

        # Iterate over the DataLoader for training data
        for i, data in enumerate(trainloader, 0):

            # Get inputs
            inputs, targets = data
            inputs, targets = inputs.to(device), targets.to(device)

            # Zero the gradients
            optimizer.zero_grad()

            # Perform forward pass
            outputs = mlp(inputs)

            # Compute loss
            loss = loss_function(outputs, targets)

            # Specify L1 and L2 weights
            l1_weight = 0#0.0001
            l2_weight = 0#0.0001

            # Compute L1 and L2 loss component
            parameters = []
            for parameter in mlp.parameters():
                parameters.append(parameter.view(-1))
            l1 = l1_weight * mlp.compute_l1_loss(torch.cat(parameters))
            l2 = l2_weight * mlp.compute_l2_loss(torch.cat(parameters))

            # Add L1 and L2 loss components
            loss += l1
            loss += l2

            # Perform backward pass
            loss.backward()

            # Perform optimization
            optimizer.step()

            # Print statistics
            minibatch_loss = loss.item()
            if i % 5000 == 4999:
                print('Loss after mini-batch %5d: %.5f (of which %.5f L1 loss; %0.5f L2 loss)' %
                    (i + 1, minibatch_loss, l1, l2))
                current_loss = 0.0
        if epoch%1==0:
            for count, linear in enumerate(linear_layers):
                if count==0 or count == len(linear_layers)-1:
                    continue

                norm = linear.neural_balance(linear_layers[count-1])
                norms.append(norm)
            
        # Testing the model
        correct = 0
        total = 0
        with torch.no_grad():
            for data in testloader:
                images, labels = data
                images, labels = images.to(device), labels.to(device)
                outputs = mlp(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        print('Accuracy of the network on the 10000 test images: {:.2f} %'.format(100 * correct / total))
        accuracies.append(100 * correct / total)
# Out:
# Training on cuda:0
# Starting epoch 1
# tensor([0.7468, 0.7275, 0.7349, 0.7119, 0.7189, 0.7721, 0.6890, 0.7169, 0.6952,
#         0.7372, 0.7646, 0.7128, 0.7574, 0.7795, 0.7335, 0.7766, 0.7239, 0.7190,
#         0.7434, 0.7349, 0.8003, 0.7285, 0.7286, 0.7012, 0.7259, 0.7693, 0.7180,
#         0.7447, 0.7452, 0.7463, 0.7384, 0.6996, 0.6932, 0.7321, 0.7187, 0.7150,
#         0.7120, 0.7519, 0.8521, 0.6931, 0.7338, 0.7474, 0.7401, 0.7467, 0.6997,
#         0.6961, 0.6822, 0.7105, 0.6864, 0.7336, 0.7766, 0.7250, 0.7620, 0.6805,
#         0.7859, 0.7477, 0.7277, 0.7062, 0.7468, 0.7500, 0.8735, 0.7103, 0.7479,
#         0.7681, 0.6885, 0.7444, 0.7587, 0.7426, 0.7922, 0.7477, 0.7286, 0.7417,
#         0.6961, 0.7285, 0.7021, 0.7297, 0.7941, 0.7396, 0.7257, 0.7840, 0.7291,
#         0.6914, 0.6941, 0.6765, 0.7459, 0.7438, 0.7102, 0.7641, 0.6709, 0.6994,
#         0.7233, 0.8265, 0.7492, 0.7080, 0.8662, 0.7570, 0.7236, 0.6688, 0.7821,
#         0.7255, 0.7220, 0.7357, 0.7160, 0.7669, 0.7230, 0.7209, 0.7046, 0.6922,
#         0.8526, 0.7976, 0.7177, 0.6874, 0.6889, 0.7244, 0.7653, 0.8353, 0.7349,
#         0.6966, 0.7832, 0.6899, 0.6815, 0.8408, 0.7618, 0.7013, 0.7607, 0.7337,
#         0.7362, 0.7107, 0.7178, 0.7163, 0.6906, 0.7001, 0.7243, 0.7651, 0.7164,
#         0.7122, 0.7280, 0.6748, 0.7043, 0.7152, 0.7228, 0.7235, 0.6776, 0.7241,
#         0.7347, 0.7621, 0.7243, 0.8305, 0.7227, 0.8424, 0.7104, 0.7639, 0.7348,
#         0.7363, 0.7719, 0.7711, 0.8071], device='cuda:0',
#        grad_fn=<SqrtBackward0>)
# tensor([0.8426, 0.8296, 0.8753, 0.8458, 0.8298, 0.8757, 0.8349, 0.8280, 0.8349,
#         0.8256, 0.8353, 0.8307, 0.8430, 0.8431, 0.8748, 0.8334, 0.8408, 0.8283,
#         0.8494, 0.8366, 0.8295, 0.8351, 0.8265, 0.8231, 0.8744, 0.8184, 0.8374,
#         0.8367, 0.8499, 0.8315, 0.8257, 0.8357, 0.8739, 0.8465, 0.8495, 0.8465,
#         0.8390, 0.8336, 0.8639, 0.8457, 0.8292, 0.8749, 0.8261, 0.8097, 0.8051,
#         0.8482, 0.8301, 0.8364, 0.8327, 0.8737, 0.8333, 0.8370, 0.8339, 0.8689,
#         0.8277, 0.8740, 0.8400, 0.8383, 0.8344, 0.8742, 0.8388, 0.8228, 0.8435,
#         0.8377, 0.8231, 0.8295, 0.8394, 0.8656, 0.8335, 0.8466, 0.8388, 0.8255,
#         0.8186, 0.8218, 0.8745, 0.8552, 0.8306, 0.8329, 0.8487, 0.8421, 0.8355,
#         0.8298, 0.8317, 0.8269, 0.8430, 0.8417, 0.8297, 0.8343, 0.8241, 0.8291,
#         0.8382, 0.8322, 0.8750, 0.8739, 0.8335, 0.8353, 0.8119, 0.8389, 0.8741,
#         0.8475, 0.8452, 0.8409, 0.8190, 0.8481, 0.8506, 0.8603, 0.8467, 0.8396,
#         0.8320, 0.8312, 0.8409, 0.8289, 0.8746, 0.8498, 0.8032, 0.8612, 0.8365,
#         0.8433, 0.8603, 0.8355, 0.8416, 0.8387, 0.8105, 0.8401, 0.8232, 0.8246,
#         0.8306, 0.8317], device='cuda:0', grad_fn=<SqrtBackward0>)
# Accuracy of the network on the 10000 test images: 96.01 %

# %%
mlp.named_parameters
# Out:
# <bound method Module.named_parameters of MLP(
#   (layers): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): CustomLinear(
#       (linear): Linear(in_features=784, out_features=256, bias=True)
#     )
#     (2): ReLU()
#     (3): CustomLinear(
#       (linear): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (4): ReLU()
#     (5): CustomLinear(
#       (linear): Linear(in_features=128, out_features=64, bias=True)
#     )
#     (6): ReLU()
#     (7): CustomLinear(
#       (linear): Linear(in_features=64, out_features=10, bias=True)
#     )
#   )
# )>

# %%
torch.save(mlp.state_dict(), 'model_weights.pth')

# %%
mlp1 = MLP()

# %%
mlp1.load_state_dict(torch.load('model_weights.pth'))

# Print the weights
for name, param in mlp1.named_parameters():
    if param.requires_grad:
        print(name, param.data)
# Out:
# layers.1.linear.weight tensor([[ 1.5357e-02,  1.6672e-02, -4.7057e-03,  ..., -7.9613e-03,
#           5.2276e-03,  7.5754e-03],
#         [-1.0058e-02, -1.8934e-02,  9.9951e-03,  ..., -5.6706e-03,
#          -6.9774e-05,  6.1296e-03],
#         [-4.3849e-04,  9.2392e-04,  2.5283e-03,  ..., -7.0834e-03,
#          -1.0527e-02,  3.2702e-03],
#         ...,
#         [ 1.7529e-02,  1.1495e-02,  1.2105e-02,  ...,  1.5509e-02,
#           0.0486, -0.1108,  0.0411,  0.0659, -0.0444, -0.1503, -0.1139,  0.0717,
#           0.0706, -0.0866, -0.0985, -0.0976, -0.0115, -0.1196,  0.1644, -0.0388,
#           0.0483,  0.0957, -0.0694,  0.1307, -0.1324, -0.0559,  0.0468,  0.0836,
#           0.1072, -0.0029, -0.0713,  0.0852, -0.1126, -0.1288,  0.0661, -0.1383,
#           0.0769,  0.0894,  0.0602, -0.0731,  0.0415, -0.1694,  0.1039, -0.0753,
#           0.0462, -0.1342,  0.0134,  0.1290, -0.1363,  0.0483,  0.1211,  0.1241]])
# layers.7.linear.bias tensor([-0.0034, -0.0588, -0.0899, -0.0937, -0.0376, -0.0428, -0.1426, -0.0819,
#          0.0384,  0.1162])

# %%
for name, param in mlp1.named_parameters():
    if param.requires_grad and 'weight' in name:
        print(name, param.data)
# Out:
# layers.1.linear.weight tensor([[-6.2605e-03,  1.3045e-02, -1.2973e-02,  ...,  1.0307e-03,
#           7.1100e-06,  1.1278e-02],
#         [-2.5196e-02,  3.2774e-02,  2.1402e-02,  ..., -3.1733e-02,
#          -7.0915e-03,  2.6519e-02],
#         [ 5.1893e-03,  3.2902e-02, -1.2697e-02,  ...,  3.1719e-02,
#           1.8023e-02,  1.0652e-02],
#         ...,
#         [ 1.5806e-02, -4.9704e-03,  3.5229e-02,  ..., -2.8549e-02,
#          -8.9116e-03,  2.6932e-03],
#         [-1.0318e-02,  2.2866e-02,  1.8969e-02,  ..., -9.1957e-03,
#           3.2426e-02, -1.6702e-02],
#         [-1.2679e-02,  2.1004e-02, -3.2559e-02,  ..., -1.5081e-02,
#           9.0458e-03,  3.1800e-02]])
# layers.3.linear.weight tensor([[-0.0022, -0.0061,  0.0614,  ...,  0.0380,  0.0328, -0.0294],
#         [-0.0621,  0.0584, -0.0461,  ..., -0.0414,  0.0513,  0.0181],
#         [ 0.0321,  0.0605, -0.0055,  ..., -0.0317,  0.0281,  0.0265],
#         ...,
#         [ 0.0314, -0.0466,  0.0309,  ..., -0.0234, -0.0574, -0.0420],
#         [-0.0047,  0.0323, -0.0159,  ...,  0.0232,  0.0382,  0.0490],
#         [ 0.0398, -0.0163, -0.0581,  ..., -0.0107,  0.0086, -0.0617]])
# layers.5.linear.weight tensor([[ 0.0365, -0.0549, -0.0345,  ..., -0.0413, -0.0580, -0.0125],
#         [-0.0616, -0.0570,  0.0147,  ..., -0.0530,  0.0616,  0.0382],
#         [ 0.0051, -0.0622, -0.0669,  ...,  0.0673, -0.0684,  0.0689],
#         ...,
#         [-0.0763,  0.0681, -0.0775,  ..., -0.0113, -0.0529,  0.0072],
#         [ 0.0557, -0.0643, -0.0165,  ...,  0.0017, -0.0548, -0.0425],
#         [-0.0153,  0.0725,  0.0736,  ...,  0.0725,  0.0436,  0.0193]])
# layers.7.linear.weight tensor([[ 0.0610, -0.0035,  0.0725, -0.0727,  0.1025, -0.0491, -0.0981,  0.0073,
#           0.0699, -0.0239,  0.0578,  0.0774,  0.0948, -0.0889,  0.1095, -0.0007,
#         [-0.0641,  0.1138,  0.0115,  0.1010, -0.0644, -0.0294,  0.0678,  0.0884,
#           0.0436, -0.0504,  0.0920, -0.0936, -0.1227, -0.0772, -0.0509, -0.0645,
#           0.0576, -0.0675, -0.0320,  0.1047, -0.0344, -0.1151,  0.0171,  0.1032,
#          -0.0091,  0.1239,  0.0502, -0.0714, -0.0648, -0.0403,  0.0207, -0.0853,
#          -0.0531, -0.0621, -0.0017, -0.0390, -0.0037, -0.0185, -0.0021, -0.1053,
#          -0.0196,  0.0550, -0.1092,  0.0762, -0.0547, -0.0296, -0.0898, -0.0779,
#           0.0342, -0.0409,  0.0569, -0.0370,  0.0338,  0.1237, -0.0886,  0.0682,
#          -0.0630,  0.0210, -0.0662,  0.0966, -0.0880,  0.0920, -0.0170, -0.0667],
#         [-0.0566,  0.0609,  0.1036, -0.0667, -0.1228,  0.0185,  0.0431, -0.1151,
#           0.1094, -0.0780,  0.0772,  0.0531,  0.0553,  0.0770, -0.1048, -0.1207,
#          -0.0640, -0.1131, -0.0031,  0.0054, -0.0762, -0.0453, -0.0150, -0.0252,
#          -0.0895,  0.0825,  0.1152,  0.0351,  0.0352,  0.0282,  0.0700, -0.0640,
#          -0.0766,  0.1248,  0.0925, -0.0068,  0.0304, -0.1180, -0.0750,  0.0341,
#           0.0121,  0.1183, -0.1056,  0.0845, -0.0230,  0.0215,  0.0018, -0.0945,
#          -0.0001, -0.0495, -0.0422, -0.0465, -0.0800,  0.0992,  0.0583,  0.0680,
#          -0.1053,  0.0623, -0.0667, -0.0378,  0.1061,  0.0936,  0.0129,  0.0641]])

# %%
import matplotlib.pyplot as plt

# Let's assume these are the accuracy values of your model over epochs
epochs_norm = list(range(len(norms)))

plt.figure(figsize=(10, 8))

# Create a simple line plot
plt.plot(epochs_norm, norms, linestyle='-', color='b', label='Norm')

# Add labels and title
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.title('Model Accuracy Over Epochs', fontsize=14)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Optionally, add a grid
plt.grid(True)

plt.legend(fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# ## normal training without neural balance or L2 regularization

# %%
if __name__ == '__main__':

    # Check if GPU is available
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print(f"Training on {device}")

    # Set fixed random number seed
    torch.manual_seed(42)
    
    epochs = 50

    # Prepare MNIST dataset
    train_dataset = MNIST(os.getcwd(), train=True, download=True, transform=transforms.ToTensor())
    test_dataset = MNIST(os.getcwd(), train=False, download=True, transform=transforms.ToTensor())
    
    trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=256, shuffle=True, num_workers=1)
    testloader = torch.utils.data.DataLoader(test_dataset, batch_size=256, shuffle=False, num_workers=1)

    # Initialize the MLP
    mlp = MLP().to(device)
    
    accuracies_l2= []

    # Define the loss function and optimizer
    loss_function = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(mlp.parameters(), lr=1e-3)

    # Run the training loop
    for epoch in range(epochs): # 5 epochs at maximum

        # Print epoch
        print(f'Starting epoch {epoch+1}')

        # Iterate over the DataLoader for training data
        for i, data in enumerate(trainloader, 0):

            # Get inputs
            inputs, targets = data
            inputs, targets = inputs.to(device), targets.to(device)

            # Zero the gradients
            optimizer.zero_grad()

            # Perform forward pass
            outputs = mlp(inputs)

            # Compute loss
            loss = loss_function(outputs, targets)

            # Specify L1 and L2 weights
            l1_weight = 0#0.0001
            l2_weight = 0.0001

            # Compute L1 and L2 loss component
            parameters = []
            for parameter in mlp.parameters():
                parameters.append(parameter.view(-1))
            l1 = l1_weight * mlp.compute_l1_loss(torch.cat(parameters))
            l2 = l2_weight * mlp.compute_l2_loss(torch.cat(parameters))

            # Add L1 and L2 loss components
            loss += l1
            loss += l2

            # Perform backward pass
            loss.backward()

            # Perform optimization
            optimizer.step()

            # Print statistics
            minibatch_loss = loss.item()
            if i % 5000 == 4999:
                print('Loss after mini-batch %5d: %.5f (of which %.5f L1 loss; %0.5f L2 loss)' %
                    (i + 1, minibatch_loss, l1, l2))
                current_loss = 0.0

        # Testing the model
        correct = 0
        total = 0
        with torch.no_grad():
            for data in testloader:
                images, labels = data
                images, labels = images.to(device), labels.to(device)
                outputs = mlp(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        print('Accuracy of the network on the 10000 test images: {:.2f} %'.format(100 * correct / total))
        accuracies_l2.append(100 * correct / total)
# Out:
# Training on cuda:0
# Starting epoch 1
# Accuracy of the network on the 10000 test images: 93.15 %
# Starting epoch 2
# Accuracy of the network on the 10000 test images: 95.24 %
# Starting epoch 3
# Accuracy of the network on the 10000 test images: 96.20 %
# Starting epoch 4
# Accuracy of the network on the 10000 test images: 96.65 %
# Starting epoch 5
# Accuracy of the network on the 10000 test images: 96.93 %
# Starting epoch 6
# Accuracy of the network on the 10000 test images: 97.49 %
# Starting epoch 7
# Accuracy of the network on the 10000 test images: 97.41 %
# Starting epoch 8
# Accuracy of the network on the 10000 test images: 97.65 %
# Starting epoch 9
# Accuracy of the network on the 10000 test images: 97.32 %
# Starting epoch 10
# Accuracy of the network on the 10000 test images: 97.50 %
# Starting epoch 11
# Accuracy of the network on the 10000 test images: 97.80 %
# Starting epoch 12
# Accuracy of the network on the 10000 test images: 97.81 %
# Starting epoch 13
# Accuracy of the network on the 10000 test images: 97.58 %
# Starting epoch 14
# Accuracy of the network on the 10000 test images: 97.78 %
# Starting epoch 15
# Accuracy of the network on the 10000 test images: 97.94 %
# Starting epoch 16
# Accuracy of the network on the 10000 test images: 97.63 %
# Starting epoch 17
# Accuracy of the network on the 10000 test images: 97.83 %
# Starting epoch 18
# Accuracy of the network on the 10000 test images: 97.91 %
# Starting epoch 19
# Accuracy of the network on the 10000 test images: 97.42 %
# Starting epoch 20
# Accuracy of the network on the 10000 test images: 97.88 %
# Starting epoch 21
# Accuracy of the network on the 10000 test images: 97.98 %
# Starting epoch 22
# Accuracy of the network on the 10000 test images: 97.82 %
# Starting epoch 23
# Accuracy of the network on the 10000 test images: 97.98 %
# Starting epoch 24
# Accuracy of the network on the 10000 test images: 97.63 %
# Starting epoch 25
# Accuracy of the network on the 10000 test images: 97.84 %
# Starting epoch 26
# Accuracy of the network on the 10000 test images: 98.14 %
# Starting epoch 27
# Accuracy of the network on the 10000 test images: 97.90 %
# Starting epoch 28
# Accuracy of the network on the 10000 test images: 97.99 %
# Starting epoch 29
# Accuracy of the network on the 10000 test images: 97.92 %
# Starting epoch 30
# Accuracy of the network on the 10000 test images: 97.96 %
# Starting epoch 31
# Accuracy of the network on the 10000 test images: 98.01 %
# Starting epoch 32
# Accuracy of the network on the 10000 test images: 98.03 %
# Starting epoch 33
# Accuracy of the network on the 10000 test images: 98.08 %
# Starting epoch 34
# Accuracy of the network on the 10000 test images: 98.08 %
# Starting epoch 35
# Accuracy of the network on the 10000 test images: 98.11 %
# Starting epoch 36
# Accuracy of the network on the 10000 test images: 97.81 %
# Starting epoch 37
# Accuracy of the network on the 10000 test images: 98.08 %
# Starting epoch 38
# Accuracy of the network on the 10000 test images: 97.82 %
# Starting epoch 39
# Accuracy of the network on the 10000 test images: 98.06 %
# Starting epoch 40
# Accuracy of the network on the 10000 test images: 98.04 %
# Starting epoch 41
# Accuracy of the network on the 10000 test images: 97.93 %
# Starting epoch 42
# Accuracy of the network on the 10000 test images: 97.83 %
# Starting epoch 43
# Accuracy of the network on the 10000 test images: 97.48 %
# Starting epoch 44
# Accuracy of the network on the 10000 test images: 98.20 %
# Starting epoch 45
# Accuracy of the network on the 10000 test images: 98.04 %
# Starting epoch 46
# Accuracy of the network on the 10000 test images: 98.27 %
# Starting epoch 47
# Accuracy of the network on the 10000 test images: 98.28 %
# Starting epoch 48
# Accuracy of the network on the 10000 test images: 98.12 %
# Starting epoch 49
# Accuracy of the network on the 10000 test images: 97.85 %
# Starting epoch 50
# Accuracy of the network on the 10000 test images: 97.76 %

# %% [markdown]
# ## with L2 regularizer

# %%
if __name__ == '__main__':

    # Check if GPU is available
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print(f"Training on {device}")

    # Set fixed random number seed
    torch.manual_seed(42)
    
    epochs = 50

    # Prepare MNIST dataset
    train_dataset = MNIST(os.getcwd(), train=True, download=True, transform=transforms.ToTensor())
    test_dataset = MNIST(os.getcwd(), train=False, download=True, transform=transforms.ToTensor())
    
    trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=256, shuffle=True, num_workers=1)
    testloader = torch.utils.data.DataLoader(test_dataset, batch_size=256, shuffle=False, num_workers=1)

    # Initialize the MLP
    mlp = MLP().to(device)
    
    accuracies_clean= []

    # Define the loss function and optimizer
    loss_function = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(mlp.parameters(), lr=1e-3)

    # Run the training loop
    for epoch in range(epochs): # 5 epochs at maximum

        # Print epoch
        print(f'Starting epoch {epoch+1}')

        # Iterate over the DataLoader for training data
        for i, data in enumerate(trainloader, 0):

            # Get inputs
            inputs, targets = data
            inputs, targets = inputs.to(device), targets.to(device)

            # Zero the gradients
            optimizer.zero_grad()

            # Perform forward pass
            outputs = mlp(inputs)

            # Compute loss
            loss = loss_function(outputs, targets)

            # Specify L1 and L2 weights
            l1_weight = 0#0.0001
            l2_weight = 0#0.0001

            # Compute L1 and L2 loss component
            parameters = []
            for parameter in mlp.parameters():
                parameters.append(parameter.view(-1))
            l1 = l1_weight * mlp.compute_l1_loss(torch.cat(parameters))
            l2 = l2_weight * mlp.compute_l2_loss(torch.cat(parameters))

            # Add L1 and L2 loss components
            loss += l1
            loss += l2

            # Perform backward pass
            loss.backward()

            # Perform optimization
            optimizer.step()

            # Print statistics
            minibatch_loss = loss.item()
            if i % 5000 == 4999:
                print('Loss after mini-batch %5d: %.5f (of which %.5f L1 loss; %0.5f L2 loss)' %
                    (i + 1, minibatch_loss, l1, l2))
                current_loss = 0.0

        # Testing the model
        correct = 0
        total = 0
        with torch.no_grad():
            for data in testloader:
                images, labels = data
                images, labels = images.to(device), labels.to(device)
                outputs = mlp(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        print('Accuracy of the network on the 10000 test images: {:.2f} %'.format(100 * correct / total))
        accuracies_clean.append(100 * correct / total)
# Out:
# Training on cuda:0
# Starting epoch 1
# Accuracy of the network on the 10000 test images: 93.26 %
# Starting epoch 2
# Accuracy of the network on the 10000 test images: 95.44 %
# Starting epoch 3
# Accuracy of the network on the 10000 test images: 96.19 %
# Starting epoch 4
# Accuracy of the network on the 10000 test images: 96.86 %
# Starting epoch 5
# Accuracy of the network on the 10000 test images: 97.42 %
# Starting epoch 6
# Accuracy of the network on the 10000 test images: 97.62 %
# Starting epoch 7
# Accuracy of the network on the 10000 test images: 97.31 %
# Starting epoch 8
# Accuracy of the network on the 10000 test images: 97.56 %
# Starting epoch 9
# Accuracy of the network on the 10000 test images: 97.79 %
# Starting epoch 10
# Accuracy of the network on the 10000 test images: 97.66 %
# Starting epoch 11
# Accuracy of the network on the 10000 test images: 97.70 %
# Starting epoch 12
# Accuracy of the network on the 10000 test images: 97.81 %
# Starting epoch 13
# Accuracy of the network on the 10000 test images: 97.39 %
# Starting epoch 14
# Accuracy of the network on the 10000 test images: 97.87 %
# Starting epoch 15
# Accuracy of the network on the 10000 test images: 97.79 %
# Starting epoch 16
# Accuracy of the network on the 10000 test images: 97.73 %
# Starting epoch 17
# Accuracy of the network on the 10000 test images: 97.69 %
# Starting epoch 18
# Accuracy of the network on the 10000 test images: 97.95 %
# Starting epoch 19
# Accuracy of the network on the 10000 test images: 97.74 %
# Starting epoch 20
# Accuracy of the network on the 10000 test images: 97.61 %
# Starting epoch 21
# Accuracy of the network on the 10000 test images: 97.51 %
# Starting epoch 22
# Accuracy of the network on the 10000 test images: 97.63 %
# Starting epoch 23
# Accuracy of the network on the 10000 test images: 97.38 %
# Starting epoch 24
# Accuracy of the network on the 10000 test images: 97.93 %
# Starting epoch 25
# Accuracy of the network on the 10000 test images: 97.65 %
# Starting epoch 26
# Accuracy of the network on the 10000 test images: 97.96 %
# Starting epoch 27
# Accuracy of the network on the 10000 test images: 97.95 %
# Starting epoch 28
# Accuracy of the network on the 10000 test images: 98.00 %
# Starting epoch 29
# Accuracy of the network on the 10000 test images: 98.08 %
# Starting epoch 30
# Accuracy of the network on the 10000 test images: 98.10 %
# Starting epoch 31
# Accuracy of the network on the 10000 test images: 98.09 %
# Starting epoch 32
# Accuracy of the network on the 10000 test images: 98.09 %
# Starting epoch 33
# Accuracy of the network on the 10000 test images: 98.08 %
# Starting epoch 34
# Accuracy of the network on the 10000 test images: 98.09 %
# Starting epoch 35
# Accuracy of the network on the 10000 test images: 98.09 %
# Starting epoch 36
# Accuracy of the network on the 10000 test images: 98.09 %
# Starting epoch 37
# Accuracy of the network on the 10000 test images: 98.09 %
# Starting epoch 38
# Accuracy of the network on the 10000 test images: 98.07 %
# Starting epoch 39
# Accuracy of the network on the 10000 test images: 98.08 %
# Starting epoch 40
# Accuracy of the network on the 10000 test images: 98.11 %
# Starting epoch 41
# Accuracy of the network on the 10000 test images: 98.09 %
# Starting epoch 42
# Accuracy of the network on the 10000 test images: 98.09 %
# Starting epoch 43
# Accuracy of the network on the 10000 test images: 98.11 %
# Starting epoch 44
# Accuracy of the network on the 10000 test images: 98.12 %
# Starting epoch 45
# Accuracy of the network on the 10000 test images: 98.10 %
# Starting epoch 46
# Accuracy of the network on the 10000 test images: 98.13 %
# Starting epoch 47
# Accuracy of the network on the 10000 test images: 98.15 %
# Starting epoch 48
# Accuracy of the network on the 10000 test images: 98.16 %
# Starting epoch 49
# Accuracy of the network on the 10000 test images: 98.14 %
# Starting epoch 50
# Accuracy of the network on the 10000 test images: 98.13 %

# %% [markdown]
# # Evaluation where neural balance takes place every batch update without ReLU

# %%
import matplotlib.pyplot as plt

# Let's assume these are the accuracy values of your model over epochs
epochs_plot = list(range(50))

plt.figure(figsize=(10, 8))

# Create a simple line plot
plt.plot(epochs_plot, accuracies_clean, linestyle='-', color='b', label='Clean Accuracy')
plt.plot(epochs_plot, accuracies, linestyle='-', color='r', label='With Neural Balance')
plt.plot(epochs_plot, accuracies_l2, linestyle='-', color='g', label='With L2 regularizer')

# Add labels and title
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.title('Model Accuracy Over Epochs', fontsize=14)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Optionally, add a grid
plt.grid(True)

plt.legend(fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# # Evaluation where neural balance takes place every batch update

# %%
import matplotlib.pyplot as plt

# Let's assume these are the accuracy values of your model over epochs
epochs_plot = list(range(50))

plt.figure(figsize=(10, 8))

# Create a simple line plot
plt.plot(epochs_plot, accuracies_clean, linestyle='-', color='b', label='Clean Accuracy')
plt.plot(epochs_plot, accuracies, linestyle='-', color='r', label='With Neural Balance')
plt.plot(epochs_plot, accuracies_l2, linestyle='-', color='g', label='With L2 regularizer')

# Add labels and title
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.title('Model Accuracy Over Epochs', fontsize=14)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Optionally, add a grid
plt.grid(True)

plt.legend(fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# # Evaluation where neural balance takes place every epoch update

# %%
import matplotlib.pyplot as plt

# Let's assume these are the accuracy values of your model over epochs
epochs_plot = list(range(50))

plt.figure(figsize=(10, 8))

# Create a simple line plot
plt.plot(epochs_plot, accuracies_clean, linestyle='-', color='b', label='Clean Accuracy')
plt.plot(epochs_plot, accuracies, linestyle='-', color='r', label='With Neural Balance')
plt.plot(epochs_plot, accuracies_l2, linestyle='-', color='g', label='With L2 regularizer')

# Add labels and title
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.title('Model Accuracy Over Epochs', fontsize=14)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Optionally, add a grid
plt.grid(True)

plt.legend(fontsize=14)

# Show the plot
plt.show()
